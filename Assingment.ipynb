# %% [markdown]
# <a href="https://colab.research.google.com/github/indra-2022/ML-Basics/blob/main/Assingment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import X
import numpy as np
x = np.array([1, 2, 3, 4])
y = np.array([1,2,3,4])
print(x)
print(y)
print(x+y)
# Out:
# [1 2 3 4]
# [1 2 3 4]
# [2 4 6 8]

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1, 2, 3, 4])
y = np.array([5, 6, 7, 8])
result = x * y
print(result)

plt.plot(result)
plt.show()
# Out:
# [ 5 12 21 32]

# %%
import numpy as np

# Create two 2D arrays
x = np.array([[1, 2], [3, 4]])
y = np.array([[5, 6], [7, 8]])

add = x + y
subtract = x - y
print("Addition:")
print(add)

print("Subtraction:")
print(subtract)
# Out:
# Addition:
# [[ 6  8]
#  [10 12]]
# Subtraction:
# [[-4 -4]
#  [-4 -4]]
